# %%
import sys
import os

sys.path.append('..')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/clustering_data.csv', header=None)
data = df.values

# %%
plt.scatter(data[:, 0], data[:, 1], marker='x')
plt.title('Scatter plot dos dados')
# Out:
# Text(0.5, 1.0, 'Scatter plot dos dados')

# %% [markdown]
# # **GMM**

# %%
from amaprob.models.gaussian_mixture_model import GaussianMixtureModel
from scipy.stats import multivariate_normal

# %%
alpha = np.zeros((1, 5))
alpha = np.zeros((1, 5))
pi = np.ones((1, 5))
mu = np.random.rand(5, 2)
sigma = 10 * np.array([np.identity(2) for _ in range(5)])
m_0 = np.zeros((1, 2))
S = 10 * np.identity(2)
kapa = 0.01
v = 4.0

# %%
model = GaussianMixtureModel(
    5, alpha, pi, mu, sigma, m_0, kapa, v, S
)

# %%
model.fit(data, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.fit(data, 10)
#
# File ~/Documents/UFC/20242/AmaProb/src/../amaprob/models/gaussian_mixture_model.py:71, in GaussianMixtureModel.fit(self, X, num_epochs)
#      69 for e in range(num_epochs):
#      70     self.step_e(X)
# ---> 71     self.step_m(X)
#
# File ~/Documents/UFC/20242/AmaProb/src/../amaprob/models/gaussian_mixture_model.py:49, in GaussianMixtureModel.step_m(self, X)
#      47 x_bar = np.zeros(self.mu.shape)
#      48 for k in range(self.K):
# ---> 49     self.pi[:, k] = (self.alpha[k] - 1 + self.r[:, k].sum()) / (N - self.K + self.alpha.sum())
#      50     x_bar[k] = np.array([self.r[i, k] * X[i] for i in range(N)]).sum(axis=0) / self.r[:, k].sum()
#      51     self.mu[k] = (self.kapa_0 * self.m_0 + x_bar[k] * self.r[:, k].sum()) / (self.kapa_0 + self.r[:, k].sum())
#
# ...

# %%
model.sigma[0]
# Out:
# array([[10.,  0.],
#        [ 0., 10.]])
